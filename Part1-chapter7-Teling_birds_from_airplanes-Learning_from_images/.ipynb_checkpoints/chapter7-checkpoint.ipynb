# %%
from torchvision import datasets
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
data_path = '../data-unversioned/p1ch7/'

# %%
cifar10 = datasets.CIFAR10(data_path,train=True,download=True)
cifar10_val = datasets.CIFAR10(data_path,train=False,download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
cifar10_val = datasets.CIFAR10(data_path,train=False,download=True)
# Out:
# Files already downloaded and verified

# %%
type(cifar10).__mro__
# Out:
# (torchvision.datasets.cifar.CIFAR10,
#  torchvision.datasets.vision.VisionDataset,
#  torch.utils.data.dataset.Dataset,
#  typing.Generic,
#  object)

# %%
len(cifar10)
# Out:
# 50000

# %%
import matplotlib.pyplot as plt
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

fig = plt.figure(figsize=(8,3))
num_classes = 10

for i in range(num_classes):
    ax = fig.add_subplot(2,5,1+i,xticks=[],yticks=[])
    ax.set_title(class_names[i])
    img = next(img for img,label in cifar10 if label== i)
    plt.imshow(img)
plt.show()

# %%
img,label = cifar10[99]

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x21F35FE6940>

# %%
label
# Out:
# 1

# %%
class_names[label]
# Out:
# 'automobile'

# %%
plt.imshow(img)
plt.show()

# %%
from torchvision import transforms
dir(transforms)
# Out:
# ['AutoAugment',
#  'AutoAugmentPolicy',
#  'CenterCrop',
#  'ColorJitter',
#  'Compose',
#  'ConvertImageDtype',
#  'FiveCrop',
#  'GaussianBlur',
#  'Grayscale',
#  'InterpolationMode',
#  'Lambda',
#  'LinearTransformation',
#  'Normalize',
#  'PILToTensor',
#  'Pad',
#  'RandomAdjustSharpness',
#  'RandomAffine',
#  'RandomApply',
#  'RandomAutocontrast',
#  'RandomChoice',
#  'RandomCrop',
#  'RandomEqualize',
#  'RandomErasing',
#  'RandomGrayscale',
#  'RandomHorizontalFlip',
#  'RandomInvert',
#  'RandomOrder',
#  'RandomPerspective',
#  'RandomPosterize',
#  'RandomResizedCrop',
#  'RandomRotation',
#  'RandomSizedCrop',
#  'RandomSolarize',
#  'RandomVerticalFlip',
#  'Resize',
#  'Scale',
#  'TenCrop',
#  'ToPILImage',
#  'ToTensor',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'autoaugment',
#  'functional',
#  'functional_pil',
#  'functional_tensor',
#  'transforms']

# %%
from torchvision import transforms

to_tensor = transforms.ToTensor()
img_t = to_tensor(img)
img_t.shape
# Out:
# torch.Size([3, 32, 32])

# %%
tensor_cifar10 = datasets.CIFAR10(data_path,train=True,download=False,transform=transforms.ToTensor())

# %%
img_t, _ = tensor_cifar10[99]
type(img_t)
# Out:
# torch.Tensor

# %%
img_t.shape, img_t.dtype
# Out:
# (torch.Size([3, 32, 32]), torch.float32)

# %%
img_t.min(),img_t.max()
# Out:
# (tensor(0.), tensor(1.))

# %%
plt.imshow(img_t.permute(1,2,0))
plt.show()

# %%
import torch,torchvision
imgs = torch.stack([img_t for img_t,_ in tensor_cifar10],dim=3)
imgs.shape
# Out:
# torch.Size([3, 32, 32, 50000])

# %%
imgs.view(3,-1).mean(dim=1)
# Out:
# tensor([0.4914, 0.4822, 0.4465])

# %%
imgs.view(3,-1).std(dim=1)
# Out:
# tensor([0.2470, 0.2435, 0.2616])

# %%
transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2470, 0.2435, 0.2616))
# Out:
# Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.247, 0.2435, 0.2616))

# %%
transformed_cifar10 = datasets.CIFAR10(
data_path,train=True,download=False,
transform=transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                        (0.2470, 0.2435, 0.2616))
]))

# %%
img_t,_ = transformed_cifar10[99]
plt.imshow(img_t.permute(1,2,0))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class_names
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
label_map = {0:0,2:1}

# %%
class_names = ['airplane','bird']

# %%
cifar2 = [(img,label_map[label]) for img,label in cifar10 if label in [0,2]]

# %%
label_map
# Out:
# {0: 0, 2: 1}

# %%
cifar2_val = [(img,label_map[label]) for img,label in cifar10_val if label in [0,2]]

# %%
import torch.nn as nn

n_out = 2

model = nn.Sequential(
    nn.Linear(3072,512,),
    nn.Tanh(),
    nn.Linear(
    512,n_out,)
)

# %%
def softmax(x):
    return torch.exp(x) / torch.exp(x).sum()

# %%
x = torch.tensor([1.0,2.0,3.0])

# %%
softmax(x)
# Out:
# tensor([0.0900, 0.2447, 0.6652])

# %%
softmax(x).sum()
# Out:
# tensor(1.)

# %%
softmax = nn.Softmax(dim=1)

# %%
x = torch.tensor([[1.0,2.0,3.0],
                 [1.0,2.0,3.0]])

# %%
softmax(x)
# Out:
# tensor([[0.0900, 0.2447, 0.6652],
#         [0.0900, 0.2447, 0.6652]])

# %%
model = nn.Sequential(
    nn.Linear(3072,512),
    nn.Tanh(),
    nn.Linear(512,2),
    nn.Softmax(dim=1))

# %%
img, _ = cifar2[0]

plt.imshow(img.permute(1, 2, 0))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-50be3884ac1f> in <module>
#       1 img, _ = cifar2[0]
#       2
# ----> 3 plt.imshow(img.permute(1, 2, 0))
#       4 plt.show()
#
# AttributeError: 'Image' object has no attribute 'permute'

# %%
from torchvision import datasets, transforms
data_path = '../data-unversioned/p1ch7/'
cifar10 = datasets.CIFAR10(
    data_path, train=True, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
    ]))

# %%
cifar10_val = datasets.CIFAR10(
    data_path, train=False, download=False,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4915, 0.4823, 0.4468),
                             (0.2470, 0.2435, 0.2616))
    ]))

# %%
label_map = {0: 0, 2: 1}
class_names = ['airplane', 'bird']
cifar2 = [(img, label_map[label])
          for img, label in cifar10 
          if label in [0, 2]]
cifar2_val = [(img, label_map[label])
              for img, label in cifar10_val
              if label in [0, 2]]

# %%
img, _ = cifar2[0]

plt.imshow(img.permute(1, 2, 0))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img_batch = img.view(-1).unsqueeze(0)

# %%
out = model(img_batch)

# %%
out
# Out:
# tensor([[0.4344, 0.5656]], grad_fn=<SoftmaxBackward>)

# %%
_,index = torch.max(out,dim=1)

# %%
index
# Out:
# tensor([1])

# %%
model = nn.Sequential(
    nn.Linear(3072,512),
    nn.Tanh(),
    nn.Linear(512,2),
    nn.LogSoftmax(dim=1))

# %%
loss =nn.NLLLoss()

# %%
img,label = cifar2[0]

# %%
out = model(img.view(-1).unsqueeze(0))
loss(out,torch.tensor([label]))
# Out:
# tensor(0.8548, grad_fn=<NllLossBackward>)

# %%
import torch
import torch.nn as nn

model = nn.Sequential(
    nn.Linear(3072,512),
    nn.Tanh(),
    nn.Linear(512,2),
    nn.LogSoftmax(dim=1))

# %%
learning_rate = 1e-2
optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate)

# %%
loss_fn = nn.NLLLoss()
n_epochs = 100

# %%
for epoch in range(n_epochs):
    for img,label in cifar2:
        out = model(img.view(-1).unsqueeze(0))
        loss = loss_fn(out,torch.tensor([label]))
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print("Epoch:%d, Loss:%f"%(epoch,float(loss)))
# Out:
# Epoch:0, Loss:6.582234
# Epoch:1, Loss:7.333991
# Epoch:2, Loss:9.079869
# Epoch:3, Loss:6.570277
# Epoch:4, Loss:4.966450
# Epoch:5, Loss:12.391566
# Epoch:6, Loss:8.877839
# Epoch:7, Loss:4.822078
# Epoch:8, Loss:9.370694
# Epoch:9, Loss:6.087098
# Epoch:10, Loss:5.620897
# Epoch:11, Loss:8.252953
# Epoch:12, Loss:1.571486
# Epoch:13, Loss:6.394911
# Epoch:14, Loss:7.162235
# Epoch:15, Loss:5.194326
# Epoch:16, Loss:4.125450
# Epoch:17, Loss:6.835720
# Epoch:18, Loss:15.532463
# Epoch:19, Loss:11.094696
# Epoch:20, Loss:9.115938
# Epoch:21, Loss:1.368706
# Epoch:22, Loss:4.882604
# Epoch:23, Loss:12.221086
# Epoch:24, Loss:8.500922
# Epoch:25, Loss:8.385564
# Epoch:26, Loss:10.252275
# Epoch:27, Loss:1.997553
# Epoch:28, Loss:0.454019
# Epoch:29, Loss:10.436429
# Epoch:30, Loss:4.818316
# Epoch:31, Loss:8.910596
# Epoch:32, Loss:11.207694
# Epoch:33, Loss:13.781713
# Epoch:34, Loss:16.858778
# Epoch:35, Loss:11.731511
# Epoch:36, Loss:0.273029
# Epoch:37, Loss:14.942932
# Epoch:38, Loss:14.490253
# Epoch:39, Loss:9.035659
# Epoch:40, Loss:7.052148
# Epoch:41, Loss:9.503946
# Epoch:42, Loss:0.079350
# Epoch:43, Loss:20.121960
# Epoch:44, Loss:7.741539
# Epoch:45, Loss:0.657309
# Epoch:46, Loss:5.336053
# Epoch:47, Loss:6.167804
# Epoch:48, Loss:14.835966
# Epoch:49, Loss:13.030989
# Epoch:50, Loss:12.852716
# Epoch:51, Loss:6.497932
# Epoch:52, Loss:0.890411
# Epoch:53, Loss:13.016753
# Epoch:54, Loss:0.009674
# Epoch:55, Loss:0.413672
# Epoch:56, Loss:1.219845
# Epoch:57, Loss:8.440924
# Epoch:58, Loss:11.654267
# Epoch:59, Loss:3.040218
# Epoch:60, Loss:6.652060
# Epoch:61, Loss:7.375430
# Epoch:62, Loss:8.260820
# Epoch:63, Loss:4.039703
# Epoch:64, Loss:6.708034
# Epoch:65, Loss:12.624857
# Epoch:66, Loss:14.893530
# Epoch:67, Loss:0.685052
# Epoch:68, Loss:2.694528
# Epoch:69, Loss:5.693776
# Epoch:70, Loss:9.404813
# Epoch:71, Loss:0.617544
# Epoch:72, Loss:1.649674
# Epoch:73, Loss:9.171056
# Epoch:74, Loss:8.530441
# Epoch:75, Loss:10.585461
# Epoch:76, Loss:5.891090
# Epoch:77, Loss:11.322540
# Epoch:78, Loss:13.698315
# Epoch:79, Loss:12.277446
# Epoch:80, Loss:4.197008
# Epoch:81, Loss:1.877592
# Epoch:82, Loss:1.457408
# Epoch:83, Loss:2.662451
# Epoch:84, Loss:0.221471
# Epoch:85, Loss:3.433128
# Epoch:86, Loss:7.524163
# Epoch:87, Loss:19.677380
# Epoch:88, Loss:5.302728
# Epoch:89, Loss:10.589622
# Epoch:90, Loss:9.378707
# Epoch:91, Loss:14.342422
# Epoch:92, Loss:19.017317
# Epoch:93, Loss:12.264194
# Epoch:94, Loss:9.741859
# Epoch:95, Loss:15.532882
# Epoch:96, Loss:5.875857
# Epoch:97, Loss:3.075739
# Epoch:98, Loss:3.789757
# Epoch:99, Loss:7.847245

# %%
train_loader = torch.utils.data.DataLoader(cifar2,batch_size=64,shuffle=True)

# %%
import torch
import torch.nn as nn

# %%
train_loader = torch.utils.data.DataLoader(cifar2,batch_size=64,shuffle=True)

# %%
model = nn.Sequential(
    nn.Linear(3072,512),
    nn.Tanh(),
    nn.Linear(512,2),
    nn.LogSoftmax(dim=1))

# %%
device = (torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu'))

# %%
device
# Out:
# device(type='cuda')

# %%
model = model.to(device=device)

# %%
learning_rate = 1e-2

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate)
loss_fn = nn.NLLLoss()
n_epochs = 100

# %%
for epoch in range(n_epochs):
    for imgs,labels in train_loader:
        imgs = imgs.to(device=device)
        labels = labels.to(device=device)
        batch_size = imgs.shape[0]
        outputs = model(imgs.view(batch_size,-1))
        loss = loss_fn(outputs,labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print("Epoch:%d,Loss:%f" %(epoch,float(loss)))
# Out:
# Epoch:0,Loss:0.423395
# Epoch:1,Loss:0.330023
# Epoch:2,Loss:0.530660
# Epoch:3,Loss:0.461983
# Epoch:4,Loss:0.396624
# Epoch:5,Loss:0.308807
# Epoch:6,Loss:0.476837
# Epoch:7,Loss:0.376642
# Epoch:8,Loss:0.451265
# Epoch:9,Loss:0.195069
# Epoch:10,Loss:0.279992
# Epoch:11,Loss:0.201388
# Epoch:12,Loss:0.316774
# Epoch:13,Loss:0.277274
# Epoch:14,Loss:0.407560
# Epoch:15,Loss:0.498269
# Epoch:16,Loss:0.290605
# Epoch:17,Loss:0.305708
# Epoch:18,Loss:0.194400
# Epoch:19,Loss:0.416922
# Epoch:20,Loss:0.087939
# Epoch:21,Loss:0.482354
# Epoch:22,Loss:0.335207
# Epoch:23,Loss:0.340076
# Epoch:24,Loss:0.323190
# Epoch:25,Loss:0.535505
# Epoch:26,Loss:0.374132
# Epoch:27,Loss:0.344639
# Epoch:28,Loss:0.226489
# Epoch:29,Loss:0.307748
# Epoch:30,Loss:0.263523
# Epoch:31,Loss:0.261817
# Epoch:32,Loss:0.274080
# Epoch:33,Loss:0.244200
# Epoch:34,Loss:0.323919
# Epoch:35,Loss:0.324556
# Epoch:36,Loss:0.195701
# Epoch:37,Loss:0.175197
# Epoch:38,Loss:0.088923
# Epoch:39,Loss:0.222500
# Epoch:40,Loss:0.078294
# Epoch:41,Loss:0.169891
# Epoch:42,Loss:0.063574
# Epoch:43,Loss:0.071828
# Epoch:44,Loss:0.230740
# Epoch:45,Loss:0.048874
# Epoch:46,Loss:0.229394
# Epoch:47,Loss:0.068739
# Epoch:48,Loss:0.131617
# Epoch:49,Loss:0.074785
# Epoch:50,Loss:0.031483
# Epoch:51,Loss:0.125877
# Epoch:52,Loss:0.198088
# Epoch:53,Loss:0.039359
# Epoch:54,Loss:0.068663
# Epoch:55,Loss:0.135902
# Epoch:56,Loss:0.138088
# Epoch:57,Loss:0.062175
# Epoch:58,Loss:0.081896
# Epoch:59,Loss:0.064380
# Epoch:60,Loss:0.046738
# Epoch:61,Loss:0.036650
# Epoch:62,Loss:0.020245
# Epoch:63,Loss:0.020798
# Epoch:64,Loss:0.198671
# Epoch:65,Loss:0.056991
# Epoch:66,Loss:0.036341
# Epoch:67,Loss:0.052743
# Epoch:68,Loss:0.062340
# Epoch:69,Loss:0.060077
# Epoch:70,Loss:0.019859
# Epoch:71,Loss:0.019515
# Epoch:72,Loss:0.027296
# Epoch:73,Loss:0.026387
# Epoch:74,Loss:0.010488
# Epoch:75,Loss:0.035114
# Epoch:76,Loss:0.018041
# Epoch:77,Loss:0.043911
# Epoch:78,Loss:0.025095
# Epoch:79,Loss:0.018403
# Epoch:80,Loss:0.023855
# Epoch:81,Loss:0.015680
# Epoch:82,Loss:0.050882
# Epoch:83,Loss:0.044381
# Epoch:84,Loss:0.019705
# Epoch:85,Loss:0.024675
# Epoch:86,Loss:0.009225
# Epoch:87,Loss:0.014442
# Epoch:88,Loss:0.019144
# Epoch:89,Loss:0.014286
# Epoch:90,Loss:0.021512
# Epoch:91,Loss:0.014027
# Epoch:92,Loss:0.007004
# Epoch:93,Loss:0.040045
# Epoch:94,Loss:0.012424
# Epoch:95,Loss:0.009686
# Epoch:96,Loss:0.012890
# Epoch:97,Loss:0.024832
# Epoch:98,Loss:0.013339
# Epoch:99,Loss:0.003743

# %%
val_loader = torch.utils.data.DataLoader(cifar2_val,batch_size=64,shuffle=False)

# %%
correct = 0
total = 0

# %%
with torch.no_grad():
    for imgs,labels in val_loader:
        imgs = imgs.to(device=device)
        labels = labels.to(device=device)
        batch_size = imgs.shape[0]
        outputs = model(imgs.view(batch_size,-1))
        _,predicted = torch.max(outputs,dim=1)
        total += labels.shape[0]
        correct += int((predicted == labels).sum())
print("Accuracy: %f",correct/total)
# Out:
# Accuracy: %f 0.823

# %%
numel_list = [p.numel() for p in model.parameters() if 
             p.requires_grad==True]

# %%
sum(numel_list)
# Out:
# 1574402

# %%
import os
os.getcwd()
# Out:
# 'E:\\code\\dl_pytorch\\Deep-learning-with-pytorch\\Part1-chapter7-Teling_birds_from_airplanes-Learning_from_images'

# %%
import numpy

# %%
import pandas as pd
